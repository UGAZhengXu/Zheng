# %% [markdown]
# ## Lab2 Python Calculations and Built-in Data Structures (Zheng Xu)

# %% [markdown]
# # Part 1.1
# ![download.png](attachment:c65f318b-6d15-44b4-8db6-7c2d1a622330.png)

# %%
x = 10
y = 3.5
z = 13
a = x**0.5/(y+z)
print("Part a=",a)
# Out:
# Part a= 0.19165319152535634

# %%
b = (x+y)**2
print("Part b=",b)
# Out:
# Part b= 182.25

# %%
ee = 2.71828183
c = ee**(-2*x*(y+x))
print("Part c=",c)
# Out:
# Part c= 5.501610239668843e-118

# %% [markdown]
# # Part 1.2
# ![image.png](attachment:7a36a17b-21c7-46b7-b379-dd546fc20683.png)

# %%
h = (5*12+7)*2.54/100
m =70
BMI=m/h**2
print("BMI:",BMI,"kg/m^2")
# Out:
# BMI: 24.170242147568278 kg/m^2

# %% [markdown]
# # Part 1.3
# ![1675369171276.png](attachment:3f42f2a8-bc01-4126-a08e-4399c8e4a142.png)

# %%
import math
La = math.sqrt(10**2-3**2)
print("The length of other side is ", La)
# Out:
# The length of other side is  9.539392014169456

# %% [markdown]
# # Part 1.4
# ![image.png](attachment:79884535-8fae-4bc0-a3e9-adcf9e3292ae.png)

# %%
import math
a = 6
b = 2
c = -4
a1 = (-b+math.sqrt(b**2-4*a*c))/(2*a)
a2 = (-b-math.sqrt(b**2-4*a*c))/(2*a)
print(a1," ",a2)
# Out:
# 0.6666666666666666   -1.0

# %% [markdown]
# # Part 1.5
# ![image.png](attachment:9d66960e-aa6c-4b34-bb7c-60ca81bdc7fb.png)

# %%
tem_C = 40;
tem_F=9/5*tem_C-32
spe_KM=1.609344*80
print("Question a: ", tem_F, "°F")
print("Question b: ", spe_KM, "kM/h")
# Out:
# Question a:  40.0 °F
# Question b:  128.74752 kM/h

# %% [markdown]
# # Part 1.6
# ![image.png](attachment:978e493a-4cbb-4c86-bb2e-ddbace576c66.png)

# %%
# 6.1 900*(1+0.045)^t=900+81
import math
in_t = math.log((900+81)/900,1+0.045)

# 6.2 4500*(1+r)^2=4500+750
in_r = ((4500+750)/4500)**0.5-1

# 6.3 p*(1+0.05)^6=p+1230
in_p = 1230/((1+0.05)**6-1)
print("Question 6.1:", in_t, "\nQuestion 6.2:", 100*in_r, "%", "\nQuestion 6.3:", in_p)
# Out:
# Question 6.1: 1.9578326686470011
# Question 6.2: 8.012344973464348 %
# Question 6.3: 3616.629715510628

# %% [markdown]
# # Part 2.1
# ![1675805835738.png](attachment:eabd5fdf-7990-474b-a926-57badc0095bb.png)
# ![1675980238863.png](attachment:2b49b0b7-2b86-47ab-a8fe-dab107d2bbbf.png)

# %%
import math
List_A = [9,2,3,8,5,1,7,3,12,5]
# Qustion a
x = List_A[0]
y = List_A[5]
z1 = math.sqrt(x)
z2 = math.sqrt(y)
print("Answer of question a: ",x+y,"  ",z1, "  ",z2)
# Question b
List_B=[]
z3 = (x+y)**0.5
List_B.append(z3)
print("Answer of question b: ",List_B)
# Question c
List_C1=List_A[::-1]
List_r=reversed(List_A)
List_C2=list(List_r)
print("Answer of question c: ",List_C1,"or", List_C2)
# Out:
# Answer of question a:  10    3.0    1.0
# Answer of question b:  [3.1622776601683795]
# Answer of question c:  [5, 12, 3, 7, 1, 5, 8, 3, 2, 9] or [5, 12, 3, 7, 1, 5, 8, 3, 2, 9]

# %% [markdown]
# ![1675980306793.png](attachment:fb8b6632-da51-4772-b40a-277636b0abe2.png)

# %%
# Question d
print("Answer of question d: ", List_A[:-1])

# Question e
print("Answer of question e: ", List_A[1:8:3])

# Question f
print("Answer of question f: ", sorted(List_A))

# Question g
List_A.extend([2,9,10,4])
print("Answer of question g: ", len(List_A))

# Question h
del List_A
# Out:
# Answer of question d:  [9, 2, 3, 8, 5, 1, 7, 3, 12]
# Answer of question e:  [2, 5, 3]
# Answer of question f:  [1, 2, 3, 3, 5, 5, 7, 8, 9, 12]
# Answer of question g:  14

# %% [markdown]
# # Part 2.2
# ![1675986971086.png](attachment:92b9a4da-7502-4637-bcf9-2518debbfe6e.png)

# %%
import math
List_A2=[5,3,"StringVa"]
List_A2.extend([6,7,"INFO"])
print("a. The elements of List is:", List_A2)
del List_A2[2]
del List_A2[4]
print("b. The sum of remaining values is:", sum(List_A2))
# Out:
# a. The elements of List is: [5, 3, 'StringVa', 6, 7, 'INFO']
# b. The sum of remaining values is: 21

# %% [markdown]
# # Part 3
# ![image.png](attachment:1f06c009-41f2-4afb-9401-7e5e23f54eec.png)

# %%
# 3.1.a
Tuple_A=(2,(1,2),"INFO",[1,2,3])
A1=Tuple_A[0]
A2=Tuple_A[1]
A3=Tuple_A[2]
A4=Tuple_A[3]
print("The element of 4 variables: ",A1,A2,A3,A4)
# Out:
# The element of 4 variables:  2 (1, 2) INFO [1, 2, 3]

# %%
# 3.1.b
Tuple_A=(Tuple_A,)+("3.1.b",)
Tuple_A
# Out:
# ((2, (1, 2), 'INFO', [1, 2, 3]), '3.1.b')

# %%
# 3.1.c
6 in Tuple_A
# Out:
# False

# %% [markdown]
# ![image.png](attachment:efd4f51b-d26f-4dd5-bede-65cfecd9806b.png)

# %%
# 3.1.d
List_TpA=list(Tuple_A)
print("The converted List is", List_TpA)
print("The lenth of the List is", len(List_TpA))
# Out:
# The converted List is [(2, (1, 2), 'INFO', [1, 2, 3]), '3.1.b']
# The lenth of the List is 2

# %%
# 3.1.e
Tuple_B=(42,31)
Tuple_C=(Tuple_B[0]/25.4,Tuple_B[1]/25.4)
Tuple_C
# Out:
# (1.6535433070866143, 1.220472440944882)

# %%
# 3.1.f（1）
del List_TpA[0]
List_TpA
# Out:
# ['3.1.b']

# %%
# 3.1.f（2）
del Tuple_A[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 2
#       1 # 3.1.f（2）
# ----> 2 del Tuple_A[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %% [markdown]
# # 3.1.f（3）
# # Remark of problem 3.1.f, it is obvious that the elements in a tuple cannot be deleted since tuple is a special data type whose elements can not be deleted. Besides, when we use dir() to find the function tuple can use, it doesn't contain 'del'.
# # However, 'del' can be used in list as shown in 3.1.f(1). An interesting thing when solving this problem is that I used to think that changing the tuple to list (3.1.d) means change all the elements in tuple to list, it means that I use to think the converted list have 5 elements. But actually not, it only has two elements. The first is the orgianl tuple and the second is the added tuple in 3.1.b. It is found when I run 3.1.f(1). Quite interesting!!!

# %% [markdown]
# ![image.png](attachment:b16766d2-d2c7-4ecb-8662-2e1e54bd1861.png)

# %%
# 4.1.a
List_StrA=["INFO8000","\n","\75","~!@#%$^"]
for firtCH in List_StrA:
    print("The first character of each element is:", firtCH[0])
# Out:
# The first character of each element is: I
# The first character of each element is:
#
# The first character of each element is: =
# The first character of each element is: ~

# %%
# 4.1.b
for number in List_StrA:
    print("The number of each element is:", len(number))
# Out:
# The number of each element is: 8
# The number of each element is: 1
# The number of each element is: 1
# The number of each element is: 7

# %%
# 4.1.c
# This is a Quote
print(f'The world is round \\This is a Quote\\')
# Out:
# The world is round \This is a Quote\

# %% [markdown]
# ![1675991103344.png](attachment:077ee0d6-c6f8-49ca-8ab8-7a6b35c5374e.png)

# %%
# 4.1.d
print(f'This is a quarter of hundred: {100/4}')
# Out:
# This is a quarter of hundred: 25.0

# %%
# 4.1.e
Senten_A="The cost of this book is 100 bucks"
Split_Wo=Senten_A.split(" ")
print("The splited words are:", Split_Wo)
Senten_B=' '.join(Split_Wo)
print("The resored sentence is:", Senten_B)
# Out:
# The splited words are: ['The', 'cost', 'of', 'this', 'book', 'is', '100', 'bucks']
# The resored sentence is: The cost of this book is 100 bucks

# %% [markdown]
# ![image.png](attachment:fbdcf16a-e8ed-4404-af34-a9c3d9e9426f.png)

# %%
Set_A={2,4,1,3,6,2,3}
Set_B={8,3,4,6,7,9,3,5,4,10}
# 5.1.a
print(Set_A&Set_B)
# 5.1.b
print(Set_A.union(Set_B)-(Set_A&Set_B))
# 5.1.c
print(Set_A-Set_B)
# Out:
# {3, 4, 6}
# {1, 2, 5, 7, 8, 9, 10}
# {1, 2}

# %% [markdown]
# ![image.png](attachment:8f86cb7e-9ce1-4fd3-9bee-6f18126b6e63.png)

# %%
# 5.1.d
print(Set_B-Set_A)
# 5.1.e
print((Set_A-Set_B)|(Set_B-Set_A))
# 5.1.f
print(Set_A.difference(Set_B))
# 5.1.g
Set_A.remove(2)
print(Set_A)
# Out:
# {5, 7, 8, 9, 10}
# {1, 2, 5, 7, 8, 9, 10}
# {1, 2}
# {1, 3, 4, 6}

# %% [markdown]
# ![image.png](attachment:644de728-f695-4d6a-95fe-dcaa75495133.png)

# %%
#6.1.a
Dic_A={"Python":20,"Homework":15,"Lab":30,"Two":5,"Good":25,"Marks":10}
list_Akey=list(Dic_A.keys())
print(" ".join(list_Akey))
# Out:
# Python Homework Lab Two Good Marks

# %% [markdown]
# ![1675997114422.png](attachment:5642d669-4340-429d-a933-30af2e754e45.png)

# %%
#6.1.b
print(list_Akey[1],Dic_A[list_Akey[1]])
# Out:
# Homework 15

# %%
#6.1.c
List_S=sorted(list_Akey)
print(List_S[-1])
# Out:
# Two

# %%
#6.1.d
List_DicA=list(Dic_A.items())
print(List_DicA)
# Out:
# [('Python', 20), ('Homework', 15), ('Lab', 30), ('Two', 5), ('Good', 25), ('Marks', 10)]

# %%
# 6.1.e
del Dic_A[List_S[-1]]
print(Dic_A)
# Out:
# {'Python': 20, 'Homework': 15, 'Lab': 30, 'Good': 25, 'Marks': 10}
